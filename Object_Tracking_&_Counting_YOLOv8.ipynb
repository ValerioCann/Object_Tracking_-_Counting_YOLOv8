# %% [markdown]
# ## Object Tracking & Counting YOLOv8

# %%
###############
# PIP Install #
###############

# !pip install yolo
# !pip install ultralytics
# Out:
# Requirement already satisfied: yolo in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: awscli in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.32.64)
# Requirement already satisfied: boto3 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.34.64)
# Requirement already satisfied: botocore>=1.7.18 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.34.64)
# Requirement already satisfied: click in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (8.1.3)
# Requirement already satisfied: docker==3.4.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (3.4.0)
# Requirement already satisfied: jinja2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (3.1.2)
# Requirement already satisfied: keyring==8.7.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (8.7)
# Requirement already satisfied: keyrings.alt in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (5.0.0)
# Requirement already satisfied: requests in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (2.28.1)
# Requirement already satisfied: ruamel.yaml in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.18.6)
# Requirement already satisfied: tabulate in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.9.0)
# Requirement already satisfied: voluptuous in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.14.2)
# Requirement already satisfied: six>=1.4.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (1.4.1)
# Requirement already satisfied: docker-pycreds>=0.3.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (0.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (2022.9.24)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.16)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.10.1)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (6.0.1)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.4.4)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (4.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jinja2->yolo) (2.1.1)
# Requirement already satisfied: jaraco.classes in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from keyrings.alt->yolo) (3.3.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ruamel.yaml->yolo) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from rsa<4.8,>=3.1.2->awscli->yolo) (0.4.8)
# Requirement already satisfied: more-itertools in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jaraco.classes->keyrings.alt->yolo) (10.2.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Requirement already satisfied: ultralytics in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (8.1.29)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (3.8.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (9.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: psutil in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2022.9.24)
# Requirement already satisfied: typing-extensions in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.99)
# Requirement already satisfied: setuptools in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->ultralytics) (69.2.0)
# Requirement already satisfied: wheel in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->ultralytics) (0.43.0)
# Requirement already satisfied: six>=1.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
###########
# Imports #
###########

import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# %%
##########################
# Set parameters & model #
##########################

## Initialize IDs sets ##
car_ids = set()
truck_ids = set()

## Initialize segmentation model ##
model = YOLO("yolov8n-seg.pt")
filename = "video001"

## Create VideoCapture object ##
cap = cv2.VideoCapture(f"/home/valerio/code/ValerioCann/Modèles/Data/Videos//{filename}.mp4")

## Retrieve height, widht & frame per second ##
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

## Create VideoWriter object ##
out = cv2.VideoWriter(f'{filename}.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))


##########################
# Tracking & Annotations #
##########################

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break
        
    ## instantiates annotator ##
    annotator = Annotator(im0, line_width=2)
    
    ## Track objects ##
    results = model.track(im0, persist=True)

    ## Retrieve masks & track ids ##
    if results[0].boxes.id is not None and results[0].masks is not None:
        masks = results[0].masks.xy
        track_ids = results[0].boxes.id.int().cpu().tolist()

        ## Draws segmentation boxes on detected objects ##
        for mask, track_id in zip(masks, track_ids):
            annotator.seg_bbox(mask=mask,
                               mask_color=colors(track_id, True),
                               track_label=str(track_id))

            # Keep track of unique car and truck IDs
            if track_id not in car_ids and track_id not in truck_ids:
                area = cv2.contourArea(mask)
                if area > 40000:  # Adjust threshold for distinguishing between cars and trucks
                    truck_ids.add(track_id)
                else:
                    car_ids.add(track_id)

    
###################
# Text parameters #
###################


    ## Font size for text ##
    fontScale = 3.0  
    
    ## Space around text in rectangle ##
    padding = 10  
    
    ## Text ##
    text = f"Cars: {len(car_ids)}, Trucks: {len(truck_ids)}"

    ## Get text size ##
    (text_width, text_height), _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, fontScale, 2)

    ## Coordinates of the rectangle around the text ##
    rectangle_top_left = (100 - padding, 100 - text_height - padding)
    rectangle_bottom_right = (100 + text_width + padding, 100 + padding)

    ## Rectangle color - BGR ##
    rectangle_color = (0, 0, 255) 

    ## Draw the rectangle ##
    cv2.rectangle(im0, rectangle_top_left, rectangle_bottom_right, rectangle_color, cv2.FILLED)

    ## Text color - BGR ##
    text_color = (255, 255, 255)

    ## Add the text above the rectangle ##
    cv2.putText(im0, text, (100, 100), cv2.FONT_HERSHEY_SIMPLEX, fontScale, text_color, 2, cv2.LINE_AA)

    
#############################################
# Output video creation, saving and display #
#############################################

    ## adds a new frame to the output video ##
    out.write(im0)
    ## displays the frame ##
    cv2.imshow("instance-segmentation-object-tracking", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 6 cars, 2 trucks, 62.0ms
# Speed: 3.3ms preprocess, 62.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 99.9ms
# Speed: 2.3ms preprocess, 99.9ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 69.8ms
# Speed: 2.5ms preprocess, 69.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 81.8ms
# Speed: 1.8ms preprocess, 81.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 75.3ms
# Speed: 2.3ms preprocess, 75.3ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 70.7ms
# Speed: 1.9ms preprocess, 70.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 70.2ms
# Speed: 1.9ms preprocess, 70.2ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 82.3ms
# Speed: 3.2ms preprocess, 82.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 84.0ms
# Speed: 2.1ms preprocess, 84.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 79.8ms
# Speed: 2.1ms preprocess, 79.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 79.5ms
# Speed: 2.1ms preprocess, 79.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 79.4ms
# Speed: 2.4ms preprocess, 79.4ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 81.5ms
# Speed: 1.8ms preprocess, 81.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 77.6ms
# Speed: 2.9ms preprocess, 77.6ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 85.4ms
# Speed: 4.2ms preprocess, 85.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 83.2ms
# Speed: 2.9ms preprocess, 83.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 83.4ms
# Speed: 2.9ms preprocess, 83.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 79.9ms
# Speed: 1.9ms preprocess, 79.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 81.4ms
# Speed: 3.2ms preprocess, 81.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 101.2ms
# Speed: 2.4ms preprocess, 101.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 79.5ms
# Speed: 1.9ms preprocess, 79.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 79.7ms
# Speed: 3.1ms preprocess, 79.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 85.1ms
# Speed: 2.0ms preprocess, 85.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 137.5ms
# Speed: 1.9ms preprocess, 137.5ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 78.0ms
# Speed: 1.9ms preprocess, 78.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 69.5ms
# Speed: 1.9ms preprocess, 69.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 3 trucks, 77.4ms
# Speed: 1.8ms preprocess, 77.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 112.0ms
# Speed: 2.2ms preprocess, 112.0ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 73.3ms
# Speed: 1.9ms preprocess, 73.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 71.3ms
# Speed: 2.4ms preprocess, 71.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 69.1ms
# Speed: 2.2ms preprocess, 69.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 71.0ms
# Speed: 4.9ms preprocess, 71.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 70.8ms
# Speed: 1.9ms preprocess, 70.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 75.3ms
# Speed: 2.2ms preprocess, 75.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 82.0ms
# Speed: 1.8ms preprocess, 82.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 76.5ms
# Speed: 2.1ms preprocess, 76.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 75.6ms
# Speed: 1.8ms preprocess, 75.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 74.2ms
# Speed: 1.9ms preprocess, 74.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 71.9ms
# Speed: 1.7ms preprocess, 71.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 62.0ms
# Speed: 1.9ms preprocess, 62.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 62.9ms
# Speed: 1.8ms preprocess, 62.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 64.3ms
# Speed: 2.9ms preprocess, 64.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 67.8ms
# Speed: 1.8ms preprocess, 67.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 70.0ms
# Speed: 1.9ms preprocess, 70.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 67.4ms
# Speed: 1.9ms preprocess, 67.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 72.4ms
# Speed: 1.8ms preprocess, 72.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 71.6ms
# Speed: 1.8ms preprocess, 71.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 76.0ms
# Speed: 2.7ms preprocess, 76.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 75.5ms
# Speed: 1.8ms preprocess, 75.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 76.0ms
# Speed: 1.9ms preprocess, 76.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.2ms
# Speed: 1.8ms preprocess, 68.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 65.4ms
# Speed: 1.9ms preprocess, 65.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.2ms
# Speed: 1.9ms preprocess, 68.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 61.1ms
# Speed: 1.8ms preprocess, 61.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 cars, 5 trucks, 64.8ms
# Speed: 1.8ms preprocess, 64.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 64.8ms
# Speed: 1.9ms preprocess, 64.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 70.1ms
# Speed: 1.9ms preprocess, 70.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 69.8ms
# Speed: 2.2ms preprocess, 69.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 64.7ms
# Speed: 1.9ms preprocess, 64.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.2ms
# Speed: 1.8ms preprocess, 68.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.3ms
# Speed: 2.1ms preprocess, 68.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 64.6ms
# Speed: 1.9ms preprocess, 64.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 60.1ms
# Speed: 1.9ms preprocess, 60.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 81.4ms
# Speed: 1.9ms preprocess, 81.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 84.0ms
# Speed: 1.8ms preprocess, 84.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 70.6ms
# Speed: 1.9ms preprocess, 70.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 140.7ms
# Speed: 2.7ms preprocess, 140.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 74.6ms
# Speed: 1.8ms preprocess, 74.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 4 trucks, 76.0ms
# Speed: 2.5ms preprocess, 76.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 79.4ms
# Speed: 2.2ms preprocess, 79.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 77.3ms
# Speed: 1.8ms preprocess, 77.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 trucks, 75.4ms
# Speed: 1.9ms preprocess, 75.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 77.6ms
# Speed: 1.8ms preprocess, 77.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 82.7ms
# Speed: 1.8ms preprocess, 82.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 75.6ms
# Speed: 1.9ms preprocess, 75.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 74.5ms
# Speed: 1.9ms preprocess, 74.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.1ms
# Speed: 2.1ms preprocess, 68.1ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 80.2ms
# Speed: 1.8ms preprocess, 80.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 74.7ms
# Speed: 2.4ms preprocess, 74.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 62.7ms
# Speed: 1.8ms preprocess, 62.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 79.7ms
# Speed: 1.8ms preprocess, 79.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 73.2ms
# Speed: 2.4ms preprocess, 73.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 74.2ms
# Speed: 1.8ms preprocess, 74.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 77.5ms
# Speed: 2.4ms preprocess, 77.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 77.1ms
# Speed: 1.9ms preprocess, 77.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 68.9ms
# Speed: 1.8ms preprocess, 68.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 68.2ms
# Speed: 1.8ms preprocess, 68.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 69.4ms
# Speed: 1.8ms preprocess, 69.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 91.1ms
# Speed: 3.6ms preprocess, 91.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 75.4ms
# Speed: 1.8ms preprocess, 75.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 74.7ms
# Speed: 2.3ms preprocess, 74.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 76.5ms
# Speed: 1.9ms preprocess, 76.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 78.7ms
# Speed: 1.8ms preprocess, 78.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 69.7ms
# Speed: 1.9ms preprocess, 69.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 77.9ms
# Speed: 1.8ms preprocess, 77.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 75.5ms
# Speed: 1.8ms preprocess, 75.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 72.6ms
# Speed: 1.8ms preprocess, 72.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 88.0ms
# Speed: 2.1ms preprocess, 88.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 81.0ms
# Speed: 2.7ms preprocess, 81.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 68.9ms
# Speed: 1.8ms preprocess, 68.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 83.6ms
# Speed: 1.9ms preprocess, 83.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 cars, 4 trucks, 83.3ms
# Speed: 2.1ms preprocess, 83.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 72.5ms
# Speed: 1.9ms preprocess, 72.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 80.1ms
# Speed: 1.9ms preprocess, 80.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 76.5ms
# Speed: 2.1ms preprocess, 76.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 76.0ms
# Speed: 1.9ms preprocess, 76.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 85.8ms
# Speed: 1.9ms preprocess, 85.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 109.7ms
# Speed: 2.6ms preprocess, 109.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 72.6ms
# Speed: 1.9ms preprocess, 72.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 75.1ms
# Speed: 1.8ms preprocess, 75.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 74.9ms
# Speed: 1.8ms preprocess, 74.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 trucks, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 111.3ms
# Speed: 1.8ms preprocess, 111.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 74.0ms
# Speed: 2.1ms preprocess, 74.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 73.7ms
# Speed: 1.7ms preprocess, 73.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 71.1ms
# Speed: 1.8ms preprocess, 71.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 76.8ms
# Speed: 1.8ms preprocess, 76.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 73.6ms
# Speed: 2.2ms preprocess, 73.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 73.9ms
# Speed: 1.8ms preprocess, 73.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 75.4ms
# Speed: 1.9ms preprocess, 75.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 81.2ms
# Speed: 2.7ms preprocess, 81.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 80.4ms
# Speed: 3.3ms preprocess, 80.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 84.5ms
# Speed: 1.8ms preprocess, 84.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 80.8ms
# Speed: 1.8ms preprocess, 80.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 65.1ms
# Speed: 1.8ms preprocess, 65.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 83.9ms
# Speed: 1.9ms preprocess, 83.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 73.0ms
# Speed: 1.9ms preprocess, 73.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 76.0ms
# Speed: 2.4ms preprocess, 76.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 74.0ms
# Speed: 1.8ms preprocess, 74.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 77.2ms
# Speed: 1.8ms preprocess, 77.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 74.5ms
# Speed: 1.8ms preprocess, 74.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 89.4ms
# Speed: 1.9ms preprocess, 89.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 79.4ms
# Speed: 1.9ms preprocess, 79.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 73.7ms
# Speed: 1.9ms preprocess, 73.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 3 trucks, 79.3ms
# Speed: 1.9ms preprocess, 79.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 72.6ms
# Speed: 1.9ms preprocess, 72.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 3 trucks, 69.9ms
# Speed: 1.9ms preprocess, 69.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 74.7ms
# Speed: 1.8ms preprocess, 74.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 77.7ms
# Speed: 1.9ms preprocess, 77.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 80.5ms
# Speed: 2.2ms preprocess, 80.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 81.7ms
# Speed: 1.8ms preprocess, 81.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 82.2ms
# Speed: 1.8ms preprocess, 82.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 84.8ms
# Speed: 1.9ms preprocess, 84.8ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 74.9ms
# Speed: 1.9ms preprocess, 74.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 77.1ms
# Speed: 1.8ms preprocess, 77.1ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 69.6ms
# Speed: 1.9ms preprocess, 69.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 70.9ms
# Speed: 1.9ms preprocess, 70.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 70.0ms
# Speed: 1.8ms preprocess, 70.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 76.3ms
# Speed: 1.9ms preprocess, 76.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 68.6ms
# Speed: 1.7ms preprocess, 68.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 cars, 3 trucks, 71.4ms
# Speed: 1.9ms preprocess, 71.4ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 67.2ms
# Speed: 1.8ms preprocess, 67.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 90.4ms
# Speed: 2.1ms preprocess, 90.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 71.0ms
# Speed: 1.9ms preprocess, 71.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 71.7ms
# Speed: 1.8ms preprocess, 71.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 72.8ms
# Speed: 1.9ms preprocess, 72.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 66.6ms
# Speed: 1.8ms preprocess, 66.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 68.6ms
# Speed: 1.8ms preprocess, 68.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 100.9ms
# Speed: 2.1ms preprocess, 100.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 75.4ms
# Speed: 1.9ms preprocess, 75.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 69.0ms
# Speed: 2.4ms preprocess, 69.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 68.4ms
# Speed: 1.8ms preprocess, 68.4ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 68.4ms
# Speed: 1.9ms preprocess, 68.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 63.7ms
# Speed: 1.9ms preprocess, 63.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 77.4ms
# Speed: 1.8ms preprocess, 77.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 79.7ms
# Speed: 1.8ms preprocess, 79.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 75.7ms
# Speed: 1.9ms preprocess, 75.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 80.3ms
# Speed: 1.8ms preprocess, 80.3ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 80.0ms
# Speed: 1.8ms preprocess, 80.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 75.7ms
# Speed: 3.6ms preprocess, 75.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 82.2ms
# Speed: 2.2ms preprocess, 82.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 82.0ms
# Speed: 1.9ms preprocess, 82.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 84.8ms
# Speed: 3.1ms preprocess, 84.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 74.3ms
# Speed: 1.9ms preprocess, 74.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 78.9ms
# Speed: 1.9ms preprocess, 78.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 76.7ms
# Speed: 1.8ms preprocess, 76.7ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 trucks, 69.3ms
# Speed: 1.8ms preprocess, 69.3ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 74.9ms
# Speed: 1.9ms preprocess, 74.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 80.2ms
# Speed: 1.9ms preprocess, 80.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 84.3ms
# Speed: 3.0ms preprocess, 84.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 77.0ms
# Speed: 2.3ms preprocess, 77.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 82.0ms
# Speed: 1.9ms preprocess, 82.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 72.2ms
# Speed: 1.8ms preprocess, 72.2ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 74.6ms
# Speed: 1.8ms preprocess, 74.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 150.5ms
# Speed: 2.3ms preprocess, 150.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 81.3ms
# Speed: 1.9ms preprocess, 81.3ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 100.1ms
# Speed: 8.3ms preprocess, 100.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 79.6ms
# Speed: 1.8ms preprocess, 79.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 73.5ms
# Speed: 1.7ms preprocess, 73.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 90.1ms
# Speed: 2.0ms preprocess, 90.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 75.8ms
# Speed: 1.8ms preprocess, 75.8ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 74.1ms
# Speed: 2.8ms preprocess, 74.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 86.3ms
# Speed: 1.9ms preprocess, 86.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 87.9ms
# Speed: 1.8ms preprocess, 87.9ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 77.4ms
# Speed: 1.9ms preprocess, 77.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 90.0ms
# Speed: 1.9ms preprocess, 90.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 78.7ms
# Speed: 1.9ms preprocess, 78.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 85.7ms
# Speed: 1.9ms preprocess, 85.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 83.4ms
# Speed: 1.7ms preprocess, 83.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 83.2ms
# Speed: 1.8ms preprocess, 83.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 77.4ms
# Speed: 1.8ms preprocess, 77.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 82.3ms
# Speed: 1.9ms preprocess, 82.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 86.3ms
# Speed: 3.6ms preprocess, 86.3ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 74.6ms
# Speed: 2.4ms preprocess, 74.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 84.5ms
# Speed: 1.9ms preprocess, 84.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 82.8ms
# Speed: 1.8ms preprocess, 82.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 81.8ms
# Speed: 1.8ms preprocess, 81.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 74.5ms
# Speed: 1.8ms preprocess, 74.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 69.9ms
# Speed: 1.9ms preprocess, 69.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 66.1ms
# Speed: 1.9ms preprocess, 66.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 69.1ms
# Speed: 1.7ms preprocess, 69.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 74.3ms
# Speed: 2.0ms preprocess, 74.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 78.3ms
# Speed: 2.0ms preprocess, 78.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 84.9ms
# Speed: 1.8ms preprocess, 84.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 94.9ms
# Speed: 2.3ms preprocess, 94.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 81.5ms
# Speed: 1.9ms preprocess, 81.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 74.0ms
# Speed: 2.2ms preprocess, 74.0ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 76.1ms
# Speed: 3.4ms preprocess, 76.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 79.3ms
# Speed: 1.7ms preprocess, 79.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 106.6ms
# Speed: 2.2ms preprocess, 106.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 82.0ms
# Speed: 1.9ms preprocess, 82.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 81.7ms
# Speed: 2.1ms preprocess, 81.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 80.4ms
# Speed: 2.3ms preprocess, 80.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 88.1ms
# Speed: 2.4ms preprocess, 88.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 85.9ms
# Speed: 1.9ms preprocess, 85.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 85.4ms
# Speed: 1.9ms preprocess, 85.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 80.0ms
# Speed: 1.8ms preprocess, 80.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 75.3ms
# Speed: 1.7ms preprocess, 75.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 82.1ms
# Speed: 1.7ms preprocess, 82.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 83.7ms
# Speed: 2.4ms preprocess, 83.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 83.1ms
# Speed: 2.0ms preprocess, 83.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 87.0ms
# Speed: 1.7ms preprocess, 87.0ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 84.8ms
# Speed: 1.9ms preprocess, 84.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 80.5ms
# Speed: 1.8ms preprocess, 80.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 81.6ms
# Speed: 1.8ms preprocess, 81.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 77.8ms
# Speed: 1.8ms preprocess, 77.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 80.0ms
# Speed: 1.9ms preprocess, 80.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 80.9ms
# Speed: 1.7ms preprocess, 80.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 79.7ms
# Speed: 1.8ms preprocess, 79.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 76.3ms
# Speed: 1.8ms preprocess, 76.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 89.9ms
# Speed: 1.7ms preprocess, 89.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 76.2ms
# Speed: 1.8ms preprocess, 76.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 79.4ms
# Speed: 2.8ms preprocess, 79.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 85.6ms
# Speed: 1.9ms preprocess, 85.6ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 86.9ms
# Speed: 2.8ms preprocess, 86.9ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 86.6ms
# Speed: 2.2ms preprocess, 86.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 80.1ms
# Speed: 1.8ms preprocess, 80.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 77.0ms
# Speed: 1.9ms preprocess, 77.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 88.5ms
# Speed: 1.9ms preprocess, 88.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 79.2ms
# Speed: 2.0ms preprocess, 79.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 74.4ms
# Speed: 2.3ms preprocess, 74.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 75.8ms
# Speed: 1.9ms preprocess, 75.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 75.9ms
# Speed: 2.1ms preprocess, 75.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 71.5ms
# Speed: 1.8ms preprocess, 71.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 cars, 2 buss, 2 trucks, 75.1ms
# Speed: 1.7ms preprocess, 75.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 72.3ms
# Speed: 1.8ms preprocess, 72.3ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 75.0ms
# Speed: 2.3ms preprocess, 75.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 66.5ms
# Speed: 1.9ms preprocess, 66.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.
